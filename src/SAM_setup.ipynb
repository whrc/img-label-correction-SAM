# %% [markdown]
# # Clone SAM codebase from facebookresearch git repository

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!git clone https://github.com/facebookresearch/segment-anything.git "/content/drive/MyDrive/img-label-correction-SAM/SAM/segment-anything"
# Out:
# Cloning into '/content/drive/MyDrive/img-label-correction-SAM/SAM/segment-anything'...
# remote: Enumerating objects: 304, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 304 (delta 2), reused 1 (delta 1), pack-reused 299 (from 2)
# Receiving objects: 100% (304/304), 18.31 MiB | 13.10 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %% [markdown]
# # Copy the SAM checkpoints

# %% [markdown]
# **Base model**

# %%
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM/" https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Out:
# --2025-07-09 00:59:05--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.37.111, 13.35.37.123, 13.35.37.84, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.37.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375042383 (358M) [binary/octet-stream]
# Saving to: ‘/content/drive/MyDrive/img-label-correction-SAM/SAM/sam_vit_b_01ec64.pth’
#
# sam_vit_b_01ec64.pt 100%[===================>] 357.67M  72.8MB/s    in 5.0s
#
# 2025-07-09 00:59:10 (70.9 MB/s) - ‘/content/drive/MyDrive/img-label-correction-SAM/SAM/sam_vit_b_01ec64.pth’ saved [375042383/375042383]

# %% [markdown]
# **Large model**

# %%
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM/" https://dl.fbaipublicfiles.com/segment_anything/sam_vit_l_0b3195.pth
# Out:
# --2025-07-09 01:01:22--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_l_0b3195.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.37.84, 13.35.37.111, 13.35.37.90, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.37.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1249524607 (1.2G) [binary/octet-stream]
# Saving to: ‘/content/drive/MyDrive/img-label-correction-SAM/SAM/sam_vit_l_0b3195.pth’
#
# sam_vit_l_0b3195.pt 100%[===================>]   1.16G  69.0MB/s    in 16s
#
# 2025-07-09 01:01:39 (73.4 MB/s) - ‘/content/drive/MyDrive/img-label-correction-SAM/SAM/sam_vit_l_0b3195.pth’ saved [1249524607/1249524607]

# %% [markdown]
# **Huge model**

# %%
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM/" https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# --2025-07-09 01:02:36--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.37.90, 13.35.37.123, 13.35.37.84, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.37.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘/content/drive/MyDrive/img-label-correction-SAM/SAM/sam_vit_h_4b8939.pth’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G  77.2MB/s    in 34s
#
# 2025-07-09 01:03:09 (72.4 MB/s) - ‘/content/drive/MyDrive/img-label-correction-SAM/SAM/sam_vit_h_4b8939.pth’ saved [2564550879/2564550879]

# %% [markdown]
# # Clone SAM2 codebase from facebookresearch git repository

# %%
# %cd '/content/drive/MyDrive/img-label-correction-SAM/SAM2/segment-anything-2'
# !ls
# Out:
# /content/drive/MyDrive/img-label-correction-SAM/SAM2/segment-anything-2
# assets		    demo		 MANIFEST.in	   sam2
# backend.Dockerfile  docker-compose.yaml  notebooks	   sav_dataset
# checkpoints	    INSTALL.md		 pyproject.toml    setup.py
# CODE_OF_CONDUCT.md  LICENSE		 README.md	   tools
# CONTRIBUTING.md     LICENSE_cctorch	 RELEASE_NOTES.md  training

# %%
#!git clone https://github.com/facebookresearch/sam2.git "/content/drive/MyDrive/img-label-correction-SAM/SAM2/segment-anything-2"
# Out:
# Cloning into '/content/drive/MyDrive/img-label-correction-SAM/SAM2/segment-anything-2'...
# remote: Enumerating objects: 1070, done.
# remote: Total 1070 (delta 0), reused 0 (delta 0), pack-reused 1070 (from 1)
# Receiving objects: 100% (1070/1070), 128.11 MiB | 14.68 MiB/s, done.
# Resolving deltas: 100% (381/381), done.
# Updating files: 100% (569/569), done.

# %% [markdown]
# # Copy the SAM2 checkpoints

# %%
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM2/" https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_tiny.pt
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM2/" https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_base_plus.pt
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM2/" https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_small.pt
#!wget -P "/content/drive/MyDrive/img-label-correction-SAM/SAM2/" https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_large.pt
# Out:
# --2025-07-14 17:37:50--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_small.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.37.111, 13.35.37.90, 13.35.37.123, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.37.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184416285 (176M) [application/vnd.snesdev-page-table]
# Saving to: ‘/content/drive/MyDrive/img-label-correction-SAM/SAM2/sam2.1_hiera_small.pt’
#
# sam2.1_hiera_small. 100%[===================>] 175.87M  75.0MB/s    in 2.3s
#
# 2025-07-14 17:37:52 (75.0 MB/s) - ‘/content/drive/MyDrive/img-label-correction-SAM/SAM2/sam2.1_hiera_small.pt’ saved [184416285/184416285]
#
# --2025-07-14 17:37:52--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_large.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.37.111, 13.35.37.90, 13.35.37.123, ...
# ...
